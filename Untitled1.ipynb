# %%
# Importing standard Qiskit libraries
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit import QuantumCircuit, transpile
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.quantum_info import state_fidelity

# qiskit-ibmq-provider has been deprecated.
# Please see the Migration Guides in https://ibm.biz/provider_migration_guide for more detail.
from qiskit_ibm_runtime import QiskitRuntimeService, Sampler, Estimator, Session, Options

# Loading your IBM Quantum account(s)
service = QiskitRuntimeService(channel="ibm_quantum")

# Invoke a primitive. For more details see https://docs.quantum.ibm.com/run/primitives
# result = Sampler().run(circuits).result()
# Out:
# qiskit_runtime_service.__init__:INFO:2024-02-21 08:33:05,333: Default instance: ibm-q/open/main

# %%
from qiskit import QuantumCircuit, Aer, execute

qc = QuantumCircuit(5, 5)
qc.x(0)  # Use () instead of [] to apply gates to qubits
qc.cu(1.91, 0, 0, 0, qc[0], qc[1])  # Correct the parameters of cu operation
qc.cx(1, 0)  # Use () instead of [] to apply gates to qubits

aer_sim = Aer.get_backend('aer_simulator')  # Corrected the backend retrieval
result = execute(qc, aer_sim).result().get_statevector()  # Retrieve statevector instead of density matrix
# Out:
# Traceback (most recent call last):
#   Cell In[24], line 5
#     qc.cu(1.91, 0, 0, 0, qc[0], qc[1])  # Correct the parameters of cu operation
#   File /opt/conda/lib/python3.10/site-packages/qiskit/circuit/quantumcircuit.py:1123 in __getitem__
#     return self._data[item]
# IndexError: list index out of range
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=IndexError: list index out of range" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>

# %%
qreg_q = QuantumRegister(5, 'q')
creg_c = ClassicalRegister(5, 'c')

circuit.x(qreg_q[0])
circuit.cu(1.91, 0, 0, 0, qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.ch(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4])
circuit.p(0, qreg_q[0])
circuit.p(pi, qreg_q[1])
circuit.p(pi, qreg_q[2])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.cx(qreg_q[3], qreg_q[0])
circuit.cx(qreg_q[3], qreg_q[1])
circuit.cx(qreg_q[4], qreg_q[1])
circuit.cx(qreg_q[4], qreg_q[2])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4])
circuit.measure(qreg_q[3], creg_c[3])
circuit.measure(qreg_q[4], creg_c[4])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4])
circuit.reset(qreg_q[0])
circuit.reset(qreg_q[1])
circuit.reset(qreg_q[2])
circuit.reset(qreg_q[3])
circuit.reset(qreg_q[4])
circuit.x(qreg_q[0])
circuit.cu(1.91, 0, 0, 0, qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[0])
circuit.ch(qreg_q[1], qreg_q[2])
circuit.cx(qreg_q[2], qreg_q[1])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4])
circuit.p(0, qreg_q[0])
circuit.p(pi, qreg_q[1])
circuit.p(pi, qreg_q[2])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.cx(qreg_q[3], qreg_q[0])
circuit.cx(qreg_q[3], qreg_q[1])
circuit.cx(qreg_q[4], qreg_q[1])
circuit.cx(qreg_q[4], qreg_q[2])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4])
circuit.measure(qreg_q[4], creg_c[4])
circuit.measure(qreg_q[3], creg_c[3])
# @columns [0,1,2,3,4,5,6,6,6,7,8,8,9,10,11,12,13,13,14,15,16,17,18,18,18,18,18,20,21,22,23,24,25,26,26,26,27,28,28,29,30,31,32,33,34,34,35,36]


editor = CircuitComposer(circuit=circuit)
# editor

display(circuit.draw())
#  # Get the classical bit values from the result
result = execute(circuit, Aer.get_backend('qasm_simulator'), shots=1000).result()
counts = result.get_counts(circuit)
print(counts.most_frequent())
plot_histogram(result.get_counts())
# Out:
# Traceback (most recent call last):
#   Cell In[16], line 4
#     circuit.x(qreg_q[0])
# AttributeError: module 'qiskit.visualization.circuit' has no attribute 'x'
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=AttributeError: module 'qiskit.visualization.circuit' has no attribute 'x'" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>
